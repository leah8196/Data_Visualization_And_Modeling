# %% [markdown]
# # Lab Instructions
#
# You have been hired by a record executive to design a guaranteed smash hit song based on data.  The exec has decided that if you make a song that has all the most popular features of recent songs then it will definitely be a hit.  So if - for example - the most common key in the Spotify data is C# then we would want the song we are designing to also be in C#.  If a "typical" value of BPM is between 120 and 130 then we would want the song we are designing to also have a tempo between 120 and 130 BMP.
#
# Visualize and describe the distribution of:
# * BPM
# * Key
# * Mode
# * Danceability
# * Energy
# * Speechiness
# * Acousticness
#
# Based on your visualizations and calculations, what values for each of these features would make a song a guaranteed smash hit?  For quantitative features, you should propose a range of values.
#
# Use a large language model to help you write code to identify if there are any songs in the Spotify dataset that meet all of the criteria we determined.  What is/are the artist(s) and title(s) of the song?  Were any of these songs actually popular?
#
# Pick a song that you know was a smash hit. How do the values of BPM, key, mode, danceability, etc. compare to other songs?
#
# **Hint:**  Import the Spotify data using `df = pd.read_csv('spotify-2023.csv', encoding='ISO-8859-1')`.

# %% [markdown]
# **Feature	Smash Hit Value / Range**
#
# * BPM	110–140
# * Key	C#
# * Mode	Major
# * Danceability	60–80%
# * Energy	60–85%
# * Speechiness	2–10%
# * Acousticness	0–40%

# %%
import pandas as pd

df = pd.read_csv('spotify-2023.csv', encoding='ISO-8859-1')

# %%
filtered_df = df.loc[(df['bpm'] >= 110) & (df['bpm'] <= 140) & (df['mode'] == 'Major') & (df['key'] == 'C#') & (df['danceability_%'] >= 60) & (df['danceability_%'] <= 80) & (df['energy_%'] >= 60) & (df['energy_%'] <= 85) & (df['speechiness_%'] >= 2) & (df['speechiness_%'] <= 10) & (df['acousticness_%'] >= 0) & (df['acousticness_%'] <= 40) ]

filtered_df[['track_name', 'artist(s)_name', 'streams']]
# Out:
#                                        track_name              artist(s)_name  \
# 106                       Cold Heart - PNAU Remix  Dua Lipa, Elton John, Pnau
# 107                                    Dandelions                     Ruth B.
# 168                                 We Found Love      Rihanna, Calvin Harris
# 236  AMERICA HAS A PROBLEM (feat. Kendrick Lamar)    Kendrick Lamar, Beyoncï¿
# 518                                  Need To Know                    Doja Cat
# 600                         I WANNA BE YOUR SLAVE                   Mï¿½ï¿½ne
# 660                            Ginseng Strip 2002                   Yung Lean
#
#         streams
# 106  1605224506
# 107  1116995633
# 168  1235005533
# 236    57089066
# 518  1042568408
# 600   851070493
# 660   240769997

# %% [markdown]
# When the smash hit criteria was applied to the Spotify dataset several songs were identified that matched all the conditions. Many of these songs have over 1 billion streams, indicating that they were very popular. This suggests that songs aligning with our smash hit criteria are often commercially successful.

# %%
df[(df['track_name'] == 'Flowers') & (df['artist(s)_name'] == 'Miley Cyrus')]
# Out:
#    track_name artist(s)_name  artist_count  released_year  released_month  \
# 12    Flowers    Miley Cyrus             1           2023               1
#
#     released_day  in_spotify_playlists  in_spotify_charts     streams  \
# 12            12                 12211                115  1316855716
#
#     in_apple_playlists  ...  bpm  key   mode danceability_%  valence_%  \
# 12                 300  ...  118  NaN  Major             71         65
#
#    energy_% acousticness_%  instrumentalness_%  liveness_%  speechiness_%
# 12       68              6                   0           3              7
#
# [1 rows x 24 columns]

# %% [markdown]
# Flowers by Miley Cyrus was one of the top songs in 2023 and as seen by the streams has been very popular. This song falls within the ranges for the smash hit criteria on all acounts except for the Key because our data set is missing that information. This further supports the idea that songs sharing these traits tend to perform well.

# %%
df['bpm'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['bpm'].describe()
# Out:
# count    953.000000
# mean     122.540399
# std       28.057802
# min       65.000000
# 25%      100.000000
# 50%      121.000000
# 75%      140.000000
# max      206.000000
# Name: bpm, dtype: float64

# %% [markdown]
# The average tempo of songs in the dataset is approximately 123 BPM, with a media on 121 BPM. The middle 50% of songs fall between 100 and 140 BPM, indicating that popular songs tend to have a moderate to fast tempo. Based on this distribution, a BPM range of 110 - 140 BPM was selected to the smash hit criteria.

# %%
df['mode'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['mode'].value_counts()
# Out:
# mode
# Major    550
# Minor    403
# Name: count, dtype: int64

# %% [markdown]
# of the 953 songs in the dataset, 550 are in the Major mode and 403 are in the Minor mode. this indicates that Major songs are more common among popular tracks. Based on this, Major mode was chosen for the smash hit criteria.

# %%
df['key'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='key'>

# %%
df['key'].value_counts()
# Out:
# key
# C#    120
# G      96
# G#     91
# F      89
# B      81
# D      81
# A      75
# F#     73
# E      62
# A#     57
# D#     33
# Name: count, dtype: int64

# %% [markdown]
# The most common key is C#, so C# was chosen for the smash hit criteria.

# %%
df['danceability_%'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['danceability_%'].describe()
# Out:
# count    953.00000
# mean      66.96957
# std       14.63061
# min       23.00000
# 25%       57.00000
# 50%       69.00000
# 75%       78.00000
# max       96.00000
# Name: danceability_%, dtype: float64

# %% [markdown]
# The average danceability of songs in this dataset is approximately 67%, with most songs falling between 57% and 78%. Based on this distribution a danceability range of 60% - 80% was chosen for the smash hit criteria.

# %%
df['energy_%'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['energy_%'].describe()
# Out:
# count    953.000000
# mean      64.279119
# std       16.550526
# min        9.000000
# 25%       53.000000
# 50%       66.000000
# 75%       77.000000
# max       97.000000
# Name: energy_%, dtype: float64

# %% [markdown]
# The average energy was songs in this dataset is approximately 64%, with most songs falling between 53% and 77%. Based on this distribution and to reflect the energetic nature of many popular songs, a range of 60% - 85% was chosen for the smash hit criteria.

# %%
df['speechiness_%'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['speechiness_%'].describe()
# Out:
# count    953.000000
# mean      10.131165
# std        9.912888
# min        2.000000
# 25%        4.000000
# 50%        6.000000
# 75%       11.000000
# max       64.000000
# Name: speechiness_%, dtype: float64

# %% [markdown]
# Speechiness values are heavily skewed toward the lower end of the distribution. The median speechiness is approximatley 6%, and 75% of songs fall below 11%. Based on this, a speechiness range of 2% - 10% was chosen for the smash hit criteria.

# %%
df['acousticness_%'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['acousticness_%'].describe()
# Out:
# count    953.000000
# mean      27.057712
# std       25.996077
# min        0.000000
# 25%        6.000000
# 50%       18.000000
# 75%       43.000000
# max       97.000000
# Name: acousticness_%, dtype: float64

# %% [markdown]
# Acousticness shows a wide distribution, with a median of approximately 18%. Most popular songs have relatively low acousticness, suggesting a mor produced sound. based on this distribution, an acousticness range of 0% - 40% was chosen for te smash hit criteria.
